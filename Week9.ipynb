# %% [markdown]
# <a href="https://colab.research.google.com/github/dhan-jds/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import folder drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# import beberapa library yang akan digunakan selama praktikum

# %%
import cv2
import numpy as np
from PIL import Image as im
from matplotlib import pyplot as plt

# %% [markdown]
# Membuat fungsi dilasi serta tampilkan hasil dilasi pada citra dengan structuring element dilasi (SED) berbentuk square 5 x 5 tanpa menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini:

# %%
import cv2 as cv
import math
from google.colab.patches import cv2_imshow
from PIL import Image as im
import os

kernel = np.ones((5,5), np.uint8)
img = cv2.imread('/content/drive/MyDrive/pcvk/j.png')
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
plt.show()

# %% [markdown]
# Buatlah fungsi erosi serta tampilkan hasil erosi pada citra dengan Structuring Element
# Erosi (SE) berbentuk square 5 x 5 tanpa menggunakan library morphology dari
# openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar
# j.png)

# %%
img = cv2.imread('/content/drive/MyDrive/pcvk/j.png')
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
plt.show()

# %% [markdown]
# Buatlah program implementasi operasi dilasi Structuring Element Dilasi (SED)
# berbentuk square 5 x 5 dengan menggunakan library morphology dari openCV,
# sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
img = cv2.imread('/content/drive/MyDrive/pcvk/j.png',0)
ret, thresh = cv2.threshold(img, 127, 225, cv2.THRESH_BINARY)
kernel = np.ones((5,5),np.uint8)
dilasi = cv2.dilate(thresh,kernel,iterations = 1)

plt.subplot(131),plt.imshow(img,cmap = 'gray')
plt.title('Citra Awal'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(dilasi,cmap = 'gray')
plt.title('Hasil Dilasi'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Buatlah program implementasi operasi dilasi Structuring Element Erosi (SE) berbentuk
# square 5 x 5 dengan menggunakan library morphology dari openCV, sehingga
# menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
kernel = np.ones((5,5), np.uint8)
ret, thresh = cv2.threshold(img, 127, 225, cv2.THRESH_BINARY)
erosi = cv2.erode(thresh,kernel,iterations = 1)
 
 
plt.subplot(131),plt.imshow(img,cmap = 'gray')
plt.title('Citra Awal'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(erosi,cmap = 'gray')
plt.title('Hasil Dilasi'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Hasil Dilasi'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# Buatlah program implementasi operasi opening dengan Structuring Element
# berbentuk square 7 x 7 tanpa dan dengan menggunakan library morphology dari
# openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar
# j.png)

# %%
img = cv2.imread('/content/drive/MyDrive/pcvk/j.png')
plt.imshow(img)

element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7))
erosion_dst = cv2.erode(img, element)
opening_dst = cv2.dilate(erosion_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening_dst), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fe50f7e5d50>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %% [markdown]
# Buatlah program implementasi operasi dilasi dengan Structuring Element berbentuk
# Cross 3 x 3 dan 5 x 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
img = cv2.imread('/content/drive/MyDrive/pcvk/j.png')
plt.imshow(img)

kernel = np.ones((7,7), np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fe50f7c5ad0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Closing'))
